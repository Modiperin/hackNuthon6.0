# %%
from ultralytics.data.converter import convert_segment_masks_to_yolo_seg

# Replace with your actual paths and class count
convert_segment_masks_to_yolo_seg(
    masks_dir="segmentation/masks", 
    output_dir="segmentation/labels", 
    classes=2
)
# Out:
# Processing segmentation\masks\ISIC_0000000_Segmentation.png imgsz = 767 x 1022
# Unknown class for pixel value 255 in file segmentation\masks\ISIC_0000000_Segmentation.png, skipping.
# Processed and stored at segmentation\labels\ISIC_0000000_Segmentation.txt imgsz = 767 x 1022
# Processing segmentation\masks\ISIC_0000001_Segmentation.png imgsz = 767 x 1022
# Unknown class for pixel value 255 in file segmentation\masks\ISIC_0000001_Segmentation.png, skipping.
# Processed and stored at segmentation\labels\ISIC_0000001_Segmentation.txt imgsz = 767 x 1022
# Processing segmentation\masks\ISIC_0000002_Segmentation.png imgsz = 767 x 1022
# Unknown class for pixel value 255 in file segmentation\masks\ISIC_0000002_Segmentation.png, skipping.
# Processed and stored at segmentation\labels\ISIC_0000002_Segmentation.txt imgsz = 767 x 1022
# Processing segmentation\masks\ISIC_0000004_Segmentation.png imgsz = 767 x 1022
# Unknown class for pixel value 255 in file segmentation\masks\ISIC_0000004_Segmentation.png, skipping.
# Processed and stored at segmentation\labels\ISIC_0000004_Segmentation.txt imgsz = 767 x 1022
# Processing segmentation\masks\ISIC_0000006_Segmentation.png imgsz = 767 x 1022
# Unknown class for pixel value 255 in file segmentation\masks\ISIC_0000006_Segmentation.png, skipping.
# Processed and stored at segmentation\labels\ISIC_0000006_Segmentation.txt imgsz = 767 x 1022

# %%
import cv2
import numpy as np
import os

def mask_to_yolo_seg(mask_path, output_path, class_id=0):
    # Read the mask image
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    height, width = mask.shape

    # Find contours
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # If no contours found, return
    if not contours:
        return

    # Get the largest contour (assuming it's the main object)
    largest_contour = max(contours, key=cv2.contourArea)

    # Simplify the contour
    epsilon = 0.005 * cv2.arcLength(largest_contour, True)
    approx = cv2.approxPolyDP(largest_contour, epsilon, True)

    # Normalize coordinates
    normalized_coords = approx.reshape(-1, 2).astype(np.float32)
    normalized_coords[:, 0] /= width
    normalized_coords[:, 1] /= height

    # Prepare YOLO format string
    yolo_string = f"{class_id} " + " ".join([f"{x:.6f} {y:.6f}" for x, y in normalized_coords])

    # Write to output file
    with open(output_path, 'w') as f:
        f.write(yolo_string)

def process_folder(input_folder, output_folder, class_id=0):
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Process each mask in the input folder
    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            mask_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, os.path.splitext(filename)[0] + '.txt')
            mask_to_yolo_seg(mask_path, output_path, class_id)
            print(f"Processed: {filename}")

# Usage
input_folder = "segmentation/masks"
output_folder = "segmentation/labels"
class_id = 0  # Assuming all masks belong to class 0

process_folder(input_folder, output_folder, class_id)
# Out:
# Processed: ISIC_0000000_Segmentation.png
# Processed: ISIC_0000001_Segmentation.png
# Processed: ISIC_0000002_Segmentation.png
# Processed: ISIC_0000004_Segmentation.png
# Processed: ISIC_0000006_Segmentation.png

# %%
import cv2
import numpy as np
import os

def mask_to_yolo_seg(mask_path, output_path, class_id=0):
    # Read the mask image
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    height, width = mask.shape

    # Find contours
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # If no contours found, return
    if not contours:
        return

    # Get the largest contour (assuming it's the main object)
    largest_contour = max(contours, key=cv2.contourArea)

    # Simplify the contour
    epsilon = 0.005 * cv2.arcLength(largest_contour, True)
    approx = cv2.approxPolyDP(largest_contour, epsilon, True)

    # Normalize coordinates
    normalized_coords = approx.reshape(-1, 2).astype(np.float32)
    normalized_coords[:, 0] /= width
    normalized_coords[:, 1] /= height

    # Prepare YOLO format string
    yolo_string = f"{class_id} " + " ".join([f"{x:.6f} {y:.6f}" for x, y in normalized_coords])

    # Write to output file
    with open(output_path, 'w') as f:
        f.write(yolo_string)

def process_folder(input_folder, output_folder, class_id=0):
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Process each mask in the input folder
    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            mask_path = os.path.join(input_folder, filename)
            
            # Get base filename without extension and remove "_Segmentation"
            base_name = os.path.splitext(filename)[0].replace("_Segmentation", "")
            
            # Create output path with modified filename
            output_path = os.path.join(output_folder, base_name + '.txt')
            
            mask_to_yolo_seg(mask_path, output_path, class_id)
            print(f"Processed: {filename} -> {base_name}.txt")

# Usage
input_folder = "segmentation/dataset/ISBI2016_ISIC_Part3B_Training_Data/mask"
output_folder = "segmentation/dataset/ISBI2016_ISIC_Part3B_Training_Data/label"
class_id = 0  # Assuming all masks belong to class 0

process_folder(input_folder, output_folder, class_id)
# Out:
# Processed: ISIC_0000000_Segmentation.png -> ISIC_0000000.txt
# Processed: ISIC_0000001_Segmentation.png -> ISIC_0000001.txt
# Processed: ISIC_0000002_Segmentation.png -> ISIC_0000002.txt
# Processed: ISIC_0000004_Segmentation.png -> ISIC_0000004.txt
# Processed: ISIC_0000006_Segmentation.png -> ISIC_0000006.txt
# Processed: ISIC_0000007_Segmentation.png -> ISIC_0000007.txt
# Processed: ISIC_0000008_Segmentation.png -> ISIC_0000008.txt
# Processed: ISIC_0000009_Segmentation.png -> ISIC_0000009.txt
# Processed: ISIC_0000010_Segmentation.png -> ISIC_0000010.txt
# Processed: ISIC_0000011_Segmentation.png -> ISIC_0000011.txt
# Processed: ISIC_0000016_Segmentation.png -> ISIC_0000016.txt
# Processed: ISIC_0000017_Segmentation.png -> ISIC_0000017.txt
# Processed: ISIC_0000018_Segmentation.png -> ISIC_0000018.txt
# Processed: ISIC_0000019_Segmentation.png -> ISIC_0000019.txt
# Processed: ISIC_0000021_Segmentation.png -> ISIC_0000021.txt
# Processed: ISIC_0000024_Segmentation.png -> ISIC_0000024.txt
# Processed: ISIC_0000025_Segmentation.png -> ISIC_0000025.txt
# Processed: ISIC_0000026_Segmentation.png -> ISIC_0000026.txt
# Processed: ISIC_0000028_Segmentation.png -> ISIC_0000028.txt
# Processed: ISIC_0000029_Segmentation.png -> ISIC_0000029.txt
# Processed: ISIC_0000030_Segmentation.png -> ISIC_0000030.txt
# Processed: ISIC_0000031_Segmentation.png -> ISIC_0000031.txt
# Processed: ISIC_0000032_Segmentation.png -> ISIC_0000032.txt
# Processed: ISIC_0000034_Segmentation.png -> ISIC_0000034.txt
# Processed: ISIC_0000035_Segmentation.png -> ISIC_0000035.txt
# Processed: ISIC_0000038_Segmentation.png -> ISIC_0000038.txt
# Processed: ISIC_0000039_Segmentation.png -> ISIC_0000039.txt
# Processed: ISIC_0000041_Segmentation.png -> ISIC_0000041.txt
# Processed: ISIC_0000042_Segmentation.png -> ISIC_0000042.txt
# Processed: ISIC_0000044_Segmentation.png -> ISIC_0000044.txt
# Processed: ISIC_0000045_Segmentation.png -> ISIC_0000045.txt
# Processed: ISIC_0000046_Segmentation.png -> ISIC_0000046.txt
# Processed: ISIC_0000047_Segmentation.png -> ISIC_0000047.txt
# Processed: ISIC_0000048_Segmentation.png -> ISIC_0000048.txt
# Processed: ISIC_0000049_Segmentation.png -> ISIC_0000049.txt
# Processed: ISIC_0000050_Segmentation.png -> ISIC_0000050.txt
# Processed: ISIC_0000051_Segmentation.png -> ISIC_0000051.txt
# Processed: ISIC_0000054_Segmentation.png -> ISIC_0000054.txt
# Processed: ISIC_0000055_Segmentation.png -> ISIC_0000055.txt
# Processed: ISIC_0000058_Segmentation.png -> ISIC_0000058.txt
# Processed: ISIC_0000059_Segmentation.png -> ISIC_0000059.txt
# Processed: ISIC_0000060_Segmentation.png -> ISIC_0000060.txt
# Processed: ISIC_0000061_Segmentation.png -> ISIC_0000061.txt
# Processed: ISIC_0000062_Segmentation.png -> ISIC_0000062.txt
# Processed: ISIC_0000063_Segmentation.png -> ISIC_0000063.txt
# Processed: ISIC_0000065_Segmentation.png -> ISIC_0000065.txt
# Processed: ISIC_0000067_Segmentation.png -> ISIC_0000067.txt
# Processed: ISIC_0000068_Segmentation.png -> ISIC_0000068.txt
# Processed: ISIC_0000073_Segmentation.png -> ISIC_0000073.txt
# Processed: ISIC_0000074_Segmentation.png -> ISIC_0000074.txt
# Processed: ISIC_0000075_Segmentation.png -> ISIC_0000075.txt
# Processed: ISIC_0000077_Segmentation.png -> ISIC_0000077.txt
# Processed: ISIC_0000078_Segmentation.png -> ISIC_0000078.txt
# Processed: ISIC_0000079_Segmentation.png -> ISIC_0000079.txt
# Processed: ISIC_0000080_Segmentation.png -> ISIC_0000080.txt
# Processed: ISIC_0000081_Segmentation.png -> ISIC_0000081.txt
# Processed: ISIC_0000082_Segmentation.png -> ISIC_0000082.txt
# Processed: ISIC_0000085_Segmentation.png -> ISIC_0000085.txt
# Processed: ISIC_0000086_Segmentation.png -> ISIC_0000086.txt
# Processed: ISIC_0000087_Segmentation.png -> ISIC_0000087.txt
# Processed: ISIC_0000089_Segmentation.png -> ISIC_0000089.txt
# Processed: ISIC_0000091_Segmentation.png -> ISIC_0000091.txt
# Processed: ISIC_0000093_Segmentation.png -> ISIC_0000093.txt
# Processed: ISIC_0000094_Segmentation.png -> ISIC_0000094.txt
# Processed: ISIC_0000095_Segmentation.png -> ISIC_0000095.txt
# Processed: ISIC_0000096_Segmentation.png -> ISIC_0000096.txt
# Processed: ISIC_0000097_Segmentation.png -> ISIC_0000097.txt
# Processed: ISIC_0000100_Segmentation.png -> ISIC_0000100.txt
# Processed: ISIC_0000102_Segmentation.png -> ISIC_0000102.txt
# Processed: ISIC_0000103_Segmentation.png -> ISIC_0000103.txt
# Processed: ISIC_0000104_Segmentation.png -> ISIC_0000104.txt
# Processed: ISIC_0000105_Segmentation.png -> ISIC_0000105.txt
# Processed: ISIC_0000108_Segmentation.png -> ISIC_0000108.txt
# Processed: ISIC_0000109_Segmentation.png -> ISIC_0000109.txt
# Processed: ISIC_0000110_Segmentation.png -> ISIC_0000110.txt
# Processed: ISIC_0000112_Segmentation.png -> ISIC_0000112.txt
# Processed: ISIC_0000114_Segmentation.png -> ISIC_0000114.txt
# Processed: ISIC_0000116_Segmentation.png -> ISIC_0000116.txt
# Processed: ISIC_0000118_Segmentation.png -> ISIC_0000118.txt
# Processed: ISIC_0000119_Segmentation.png -> ISIC_0000119.txt
# Processed: ISIC_0000120_Segmentation.png -> ISIC_0000120.txt
# Processed: ISIC_0000121_Segmentation.png -> ISIC_0000121.txt
# Processed: ISIC_0000122_Segmentation.png -> ISIC_0000122.txt
# Processed: ISIC_0000123_Segmentation.png -> ISIC_0000123.txt
# Processed: ISIC_0000124_Segmentation.png -> ISIC_0000124.txt
# Processed: ISIC_0000127_Segmentation.png -> ISIC_0000127.txt
# Processed: ISIC_0000128_Segmentation.png -> ISIC_0000128.txt
# Processed: ISIC_0000130_Segmentation.png -> ISIC_0000130.txt
# Processed: ISIC_0000131_Segmentation.png -> ISIC_0000131.txt
# Processed: ISIC_0000133_Segmentation.png -> ISIC_0000133.txt
# Processed: ISIC_0000134_Segmentation.png -> ISIC_0000134.txt
# Processed: ISIC_0000135_Segmentation.png -> ISIC_0000135.txt
# Processed: ISIC_0000137_Segmentation.png -> ISIC_0000137.txt
# Processed: ISIC_0000139_Segmentation.png -> ISIC_0000139.txt
# Processed: ISIC_0000140_Segmentation.png -> ISIC_0000140.txt
# Processed: ISIC_0000142_Segmentation.png -> ISIC_0000142.txt
# Processed: ISIC_0000143_Segmentation.png -> ISIC_0000143.txt
# Processed: ISIC_0000145_Segmentation.png -> ISIC_0000145.txt
# Processed: ISIC_0000146_Segmentation.png -> ISIC_0000146.txt
# Processed: ISIC_0000147_Segmentation.png -> ISIC_0000147.txt
# Processed: ISIC_0000148_Segmentation.png -> ISIC_0000148.txt
# Processed: ISIC_0000150_Segmentation.png -> ISIC_0000150.txt
# Processed: ISIC_0000151_Segmentation.png -> ISIC_0000151.txt
# Processed: ISIC_0000152_Segmentation.png -> ISIC_0000152.txt
# Processed: ISIC_0000153_Segmentation.png -> ISIC_0000153.txt
# Processed: ISIC_0000154_Segmentation.png -> ISIC_0000154.txt
# Processed: ISIC_0000155_Segmentation.png -> ISIC_0000155.txt
# Processed: ISIC_0000156_Segmentation.png -> ISIC_0000156.txt
# Processed: ISIC_0000157_Segmentation.png -> ISIC_0000157.txt
# Processed: ISIC_0000159_Segmentation.png -> ISIC_0000159.txt
# Processed: ISIC_0000162_Segmentation.png -> ISIC_0000162.txt
# Processed: ISIC_0000163_Segmentation.png -> ISIC_0000163.txt
# Processed: ISIC_0000166_Segmentation.png -> ISIC_0000166.txt
# Processed: ISIC_0000167_Segmentation.png -> ISIC_0000167.txt
# Processed: ISIC_0000170_Segmentation.png -> ISIC_0000170.txt
# Processed: ISIC_0000171_Segmentation.png -> ISIC_0000171.txt
# Processed: ISIC_0000173_Segmentation.png -> ISIC_0000173.txt
# Processed: ISIC_0000175_Segmentation.png -> ISIC_0000175.txt
# Processed: ISIC_0000176_Segmentation.png -> ISIC_0000176.txt
# Processed: ISIC_0000179_Segmentation.png -> ISIC_0000179.txt
# Processed: ISIC_0000181_Segmentation.png -> ISIC_0000181.txt
# Processed: ISIC_0000182_Segmentation.png -> ISIC_0000182.txt
# Processed: ISIC_0000183_Segmentation.png -> ISIC_0000183.txt
# Processed: ISIC_0000184_Segmentation.png -> ISIC_0000184.txt
# Processed: ISIC_0000185_Segmentation.png -> ISIC_0000185.txt
# Processed: ISIC_0000186_Segmentation.png -> ISIC_0000186.txt
# Processed: ISIC_0000187_Segmentation.png -> ISIC_0000187.txt
# Processed: ISIC_0000189_Segmentation.png -> ISIC_0000189.txt
# Processed: ISIC_0000190_Segmentation.png -> ISIC_0000190.txt
# Processed: ISIC_0000191_Segmentation.png -> ISIC_0000191.txt
# Processed: ISIC_0000192_Segmentation.png -> ISIC_0000192.txt
# Processed: ISIC_0000193_Segmentation.png -> ISIC_0000193.txt
# Processed: ISIC_0000199_Segmentation.png -> ISIC_0000199.txt
# Processed: ISIC_0000203_Segmentation.png -> ISIC_0000203.txt
# Processed: ISIC_0000204_Segmentation.png -> ISIC_0000204.txt
# Processed: ISIC_0000205_Segmentation.png -> ISIC_0000205.txt
# Processed: ISIC_0000206_Segmentation.png -> ISIC_0000206.txt
# Processed: ISIC_0000207_Segmentation.png -> ISIC_0000207.txt
# Processed: ISIC_0000208_Segmentation.png -> ISIC_0000208.txt
# Processed: ISIC_0000209_Segmentation.png -> ISIC_0000209.txt
# Processed: ISIC_0000210_Segmentation.png -> ISIC_0000210.txt
# Processed: ISIC_0000211_Segmentation.png -> ISIC_0000211.txt
# Processed: ISIC_0000214_Segmentation.png -> ISIC_0000214.txt
# Processed: ISIC_0000215_Segmentation.png -> ISIC_0000215.txt
# Processed: ISIC_0000216_Segmentation.png -> ISIC_0000216.txt
# Processed: ISIC_0000217_Segmentation.png -> ISIC_0000217.txt
# Processed: ISIC_0000218_Segmentation.png -> ISIC_0000218.txt
# Processed: ISIC_0000219_Segmentation.png -> ISIC_0000219.txt
# Processed: ISIC_0000220_Segmentation.png -> ISIC_0000220.txt
# Processed: ISIC_0000221_Segmentation.png -> ISIC_0000221.txt
# Processed: ISIC_0000223_Segmentation.png -> ISIC_0000223.txt
# Processed: ISIC_0000224_Segmentation.png -> ISIC_0000224.txt
# Processed: ISIC_0000225_Segmentation.png -> ISIC_0000225.txt
# Processed: ISIC_0000229_Segmentation.png -> ISIC_0000229.txt
# Processed: ISIC_0000232_Segmentation.png -> ISIC_0000232.txt
# Processed: ISIC_0000235_Segmentation.png -> ISIC_0000235.txt
# Processed: ISIC_0000236_Segmentation.png -> ISIC_0000236.txt
# Processed: ISIC_0000237_Segmentation.png -> ISIC_0000237.txt
# Processed: ISIC_0000239_Segmentation.png -> ISIC_0000239.txt
# Processed: ISIC_0000240_Segmentation.png -> ISIC_0000240.txt
# Processed: ISIC_0000242_Segmentation.png -> ISIC_0000242.txt
# Processed: ISIC_0000243_Segmentation.png -> ISIC_0000243.txt
# Processed: ISIC_0000244_Segmentation.png -> ISIC_0000244.txt
# Processed: ISIC_0000245_Segmentation.png -> ISIC_0000245.txt
# Processed: ISIC_0000247_Segmentation.png -> ISIC_0000247.txt
# Processed: ISIC_0000249_Segmentation.png -> ISIC_0000249.txt
# Processed: ISIC_0000250_Segmentation.png -> ISIC_0000250.txt
# Processed: ISIC_0000251_Segmentation.png -> ISIC_0000251.txt
# Processed: ISIC_0000252_Segmentation.png -> ISIC_0000252.txt
# Processed: ISIC_0000255_Segmentation.png -> ISIC_0000255.txt
# Processed: ISIC_0000256_Segmentation.png -> ISIC_0000256.txt
# Processed: ISIC_0000259_Segmentation.png -> ISIC_0000259.txt
# Processed: ISIC_0000260_Segmentation.png -> ISIC_0000260.txt
# Processed: ISIC_0000261_Segmentation.png -> ISIC_0000261.txt
# Processed: ISIC_0000262_Segmentation.png -> ISIC_0000262.txt
# Processed: ISIC_0000263_Segmentation.png -> ISIC_0000263.txt
# Processed: ISIC_0000264_Segmentation.png -> ISIC_0000264.txt
# Processed: ISIC_0000265_Segmentation.png -> ISIC_0000265.txt
# Processed: ISIC_0000268_Segmentation.png -> ISIC_0000268.txt
# Processed: ISIC_0000269_Segmentation.png -> ISIC_0000269.txt
# Processed: ISIC_0000274_Segmentation.png -> ISIC_0000274.txt
# Processed: ISIC_0000275_Segmentation.png -> ISIC_0000275.txt
# Processed: ISIC_0000276_Segmentation.png -> ISIC_0000276.txt
# Processed: ISIC_0000277_Segmentation.png -> ISIC_0000277.txt
# Processed: ISIC_0000278_Segmentation.png -> ISIC_0000278.txt
# Processed: ISIC_0000280_Segmentation.png -> ISIC_0000280.txt
# Processed: ISIC_0000281_Segmentation.png -> ISIC_0000281.txt
# Processed: ISIC_0000282_Segmentation.png -> ISIC_0000282.txt
# Processed: ISIC_0000283_Segmentation.png -> ISIC_0000283.txt
# Processed: ISIC_0000285_Segmentation.png -> ISIC_0000285.txt
# Processed: ISIC_0000288_Segmentation.png -> ISIC_0000288.txt
# Processed: ISIC_0000290_Segmentation.png -> ISIC_0000290.txt
# Processed: ISIC_0000292_Segmentation.png -> ISIC_0000292.txt
# Processed: ISIC_0000293_Segmentation.png -> ISIC_0000293.txt
# Processed: ISIC_0000294_Segmentation.png -> ISIC_0000294.txt
# Processed: ISIC_0000295_Segmentation.png -> ISIC_0000295.txt
# Processed: ISIC_0000297_Segmentation.png -> ISIC_0000297.txt
# Processed: ISIC_0000300_Segmentation.png -> ISIC_0000300.txt
# Processed: ISIC_0000301_Segmentation.png -> ISIC_0000301.txt
# Processed: ISIC_0000303_Segmentation.png -> ISIC_0000303.txt
# Processed: ISIC_0000307_Segmentation.png -> ISIC_0000307.txt
# Processed: ISIC_0000313_Segmentation.png -> ISIC_0000313.txt
# Processed: ISIC_0000314_Segmentation.png -> ISIC_0000314.txt
# Processed: ISIC_0000315_Segmentation.png -> ISIC_0000315.txt
# Processed: ISIC_0000316_Segmentation.png -> ISIC_0000316.txt
# Processed: ISIC_0000317_Segmentation.png -> ISIC_0000317.txt
# Processed: ISIC_0000321_Segmentation.png -> ISIC_0000321.txt
# Processed: ISIC_0000322_Segmentation.png -> ISIC_0000322.txt
# Processed: ISIC_0000323_Segmentation.png -> ISIC_0000323.txt
# Processed: ISIC_0000324_Segmentation.png -> ISIC_0000324.txt
# Processed: ISIC_0000326_Segmentation.png -> ISIC_0000326.txt
# Processed: ISIC_0000329_Segmentation.png -> ISIC_0000329.txt
# Processed: ISIC_0000330_Segmentation.png -> ISIC_0000330.txt
# Processed: ISIC_0000331_Segmentation.png -> ISIC_0000331.txt
# Processed: ISIC_0000332_Segmentation.png -> ISIC_0000332.txt
# Processed: ISIC_0000333_Segmentation.png -> ISIC_0000333.txt
# Processed: ISIC_0000336_Segmentation.png -> ISIC_0000336.txt
# Processed: ISIC_0000337_Segmentation.png -> ISIC_0000337.txt
# Processed: ISIC_0000338_Segmentation.png -> ISIC_0000338.txt
# Processed: ISIC_0000339_Segmentation.png -> ISIC_0000339.txt
# Processed: ISIC_0000341_Segmentation.png -> ISIC_0000341.txt
# Processed: ISIC_0000342_Segmentation.png -> ISIC_0000342.txt
# Processed: ISIC_0000344_Segmentation.png -> ISIC_0000344.txt
# Processed: ISIC_0000345_Segmentation.png -> ISIC_0000345.txt
# Processed: ISIC_0000346_Segmentation.png -> ISIC_0000346.txt
# Processed: ISIC_0000347_Segmentation.png -> ISIC_0000347.txt
# Processed: ISIC_0000348_Segmentation.png -> ISIC_0000348.txt
# Processed: ISIC_0000349_Segmentation.png -> ISIC_0000349.txt
# Processed: ISIC_0000350_Segmentation.png -> ISIC_0000350.txt
# Processed: ISIC_0000351_Segmentation.png -> ISIC_0000351.txt
# Processed: ISIC_0000352_Segmentation.png -> ISIC_0000352.txt
# Processed: ISIC_0000353_Segmentation.png -> ISIC_0000353.txt
# Processed: ISIC_0000355_Segmentation.png -> ISIC_0000355.txt
# Processed: ISIC_0000358_Segmentation.png -> ISIC_0000358.txt
# Processed: ISIC_0000359_Segmentation.png -> ISIC_0000359.txt
# Processed: ISIC_0000360_Segmentation.png -> ISIC_0000360.txt
# Processed: ISIC_0000361_Segmentation.png -> ISIC_0000361.txt
# Processed: ISIC_0000363_Segmentation.png -> ISIC_0000363.txt
# Processed: ISIC_0000364_Segmentation.png -> ISIC_0000364.txt
# Processed: ISIC_0000365_Segmentation.png -> ISIC_0000365.txt
# Processed: ISIC_0000366_Segmentation.png -> ISIC_0000366.txt
# Processed: ISIC_0000367_Segmentation.png -> ISIC_0000367.txt
# Processed: ISIC_0000369_Segmentation.png -> ISIC_0000369.txt
# Processed: ISIC_0000370_Segmentation.png -> ISIC_0000370.txt
# Processed: ISIC_0000372_Segmentation.png -> ISIC_0000372.txt
# Processed: ISIC_0000374_Segmentation.png -> ISIC_0000374.txt
# Processed: ISIC_0000376_Segmentation.png -> ISIC_0000376.txt
# Processed: ISIC_0000379_Segmentation.png -> ISIC_0000379.txt
# Processed: ISIC_0000381_Segmentation.png -> ISIC_0000381.txt
# Processed: ISIC_0000382_Segmentation.png -> ISIC_0000382.txt
# Processed: ISIC_0000383_Segmentation.png -> ISIC_0000383.txt
# Processed: ISIC_0000384_Segmentation.png -> ISIC_0000384.txt
# Processed: ISIC_0000385_Segmentation.png -> ISIC_0000385.txt
# Processed: ISIC_0000386_Segmentation.png -> ISIC_0000386.txt
# Processed: ISIC_0000387_Segmentation.png -> ISIC_0000387.txt
# Processed: ISIC_0000390_Segmentation.png -> ISIC_0000390.txt
# Processed: ISIC_0000391_Segmentation.png -> ISIC_0000391.txt
# Processed: ISIC_0000395_Segmentation.png -> ISIC_0000395.txt
# Processed: ISIC_0000396_Segmentation.png -> ISIC_0000396.txt
# Processed: ISIC_0000397_Segmentation.png -> ISIC_0000397.txt
# Processed: ISIC_0000403_Segmentation.png -> ISIC_0000403.txt
# Processed: ISIC_0000408_Segmentation.png -> ISIC_0000408.txt
# Processed: ISIC_0000409_Segmentation.png -> ISIC_0000409.txt
# Processed: ISIC_0000410_Segmentation.png -> ISIC_0000410.txt
# Processed: ISIC_0000412_Segmentation.png -> ISIC_0000412.txt
# Processed: ISIC_0000413_Segmentation.png -> ISIC_0000413.txt
# Processed: ISIC_0000415_Segmentation.png -> ISIC_0000415.txt
# Processed: ISIC_0000416_Segmentation.png -> ISIC_0000416.txt
# Processed: ISIC_0000419_Segmentation.png -> ISIC_0000419.txt
# Processed: ISIC_0000421_Segmentation.png -> ISIC_0000421.txt
# Processed: ISIC_0000423_Segmentation.png -> ISIC_0000423.txt
# Processed: ISIC_0000425_Segmentation.png -> ISIC_0000425.txt
# Processed: ISIC_0000426_Segmentation.png -> ISIC_0000426.txt
# Processed: ISIC_0000427_Segmentation.png -> ISIC_0000427.txt
# Processed: ISIC_0000431_Segmentation.png -> ISIC_0000431.txt
# Processed: ISIC_0000434_Segmentation.png -> ISIC_0000434.txt
# Processed: ISIC_0000436_Segmentation.png -> ISIC_0000436.txt
# Processed: ISIC_0000439_Segmentation.png -> ISIC_0000439.txt
# Processed: ISIC_0000442_Segmentation.png -> ISIC_0000442.txt
# Processed: ISIC_0000443_Segmentation.png -> ISIC_0000443.txt
# Processed: ISIC_0000444_Segmentation.png -> ISIC_0000444.txt
# Processed: ISIC_0000445_Segmentation.png -> ISIC_0000445.txt
# Processed: ISIC_0000447_Segmentation.png -> ISIC_0000447.txt
# Processed: ISIC_0000451_Segmentation.png -> ISIC_0000451.txt
# Processed: ISIC_0000452_Segmentation.png -> ISIC_0000452.txt
# Processed: ISIC_0000453_Segmentation.png -> ISIC_0000453.txt
# Processed: ISIC_0000454_Segmentation.png -> ISIC_0000454.txt
# Processed: ISIC_0000455_Segmentation.png -> ISIC_0000455.txt
# Processed: ISIC_0000457_Segmentation.png -> ISIC_0000457.txt
# Processed: ISIC_0000458_Segmentation.png -> ISIC_0000458.txt
# Processed: ISIC_0000460_Segmentation.png -> ISIC_0000460.txt
# Processed: ISIC_0000461_Segmentation.png -> ISIC_0000461.txt
# Processed: ISIC_0000463_Segmentation.png -> ISIC_0000463.txt
# Processed: ISIC_0000465_Segmentation.png -> ISIC_0000465.txt
# Processed: ISIC_0000467_Segmentation.png -> ISIC_0000467.txt
# Processed: ISIC_0000468_Segmentation.png -> ISIC_0000468.txt
# Processed: ISIC_0000469_Segmentation.png -> ISIC_0000469.txt
# Processed: ISIC_0000471_Segmentation.png -> ISIC_0000471.txt
# Processed: ISIC_0000473_Segmentation.png -> ISIC_0000473.txt
# Processed: ISIC_0000474_Segmentation.png -> ISIC_0000474.txt
# Processed: ISIC_0000475_Segmentation.png -> ISIC_0000475.txt
# Processed: ISIC_0000477_Segmentation.png -> ISIC_0000477.txt
# Processed: ISIC_0000478_Segmentation.png -> ISIC_0000478.txt
# Processed: ISIC_0000480_Segmentation.png -> ISIC_0000480.txt
# Processed: ISIC_0000481_Segmentation.png -> ISIC_0000481.txt
# Processed: ISIC_0000483_Segmentation.png -> ISIC_0000483.txt
# Processed: ISIC_0000485_Segmentation.png -> ISIC_0000485.txt
# Processed: ISIC_0000486_Segmentation.png -> ISIC_0000486.txt
# Processed: ISIC_0000488_Segmentation.png -> ISIC_0000488.txt
# Processed: ISIC_0000489_Segmentation.png -> ISIC_0000489.txt
# Processed: ISIC_0000491_Segmentation.png -> ISIC_0000491.txt
# Processed: ISIC_0000492_Segmentation.png -> ISIC_0000492.txt
# Processed: ISIC_0000493_Segmentation.png -> ISIC_0000493.txt
# Processed: ISIC_0000495_Segmentation.png -> ISIC_0000495.txt
# Processed: ISIC_0000496_Segmentation.png -> ISIC_0000496.txt
# Processed: ISIC_0000498_Segmentation.png -> ISIC_0000498.txt
# Processed: ISIC_0000500_Segmentation.png -> ISIC_0000500.txt
# Processed: ISIC_0000503_Segmentation.png -> ISIC_0000503.txt
# Processed: ISIC_0000504_Segmentation.png -> ISIC_0000504.txt
# Processed: ISIC_0000505_Segmentation.png -> ISIC_0000505.txt
# Processed: ISIC_0000506_Segmentation.png -> ISIC_0000506.txt
# Processed: ISIC_0000507_Segmentation.png -> ISIC_0000507.txt
# Processed: ISIC_0000511_Segmentation.png -> ISIC_0000511.txt
# Processed: ISIC_0000513_Segmentation.png -> ISIC_0000513.txt
# Processed: ISIC_0000514_Segmentation.png -> ISIC_0000514.txt
# Processed: ISIC_0000516_Segmentation.png -> ISIC_0000516.txt
# Processed: ISIC_0000517_Segmentation.png -> ISIC_0000517.txt
# Processed: ISIC_0000519_Segmentation.png -> ISIC_0000519.txt
# Processed: ISIC_0000520_Segmentation.png -> ISIC_0000520.txt
# Processed: ISIC_0000521_Segmentation.png -> ISIC_0000521.txt
# Processed: ISIC_0000522_Segmentation.png -> ISIC_0000522.txt
# Processed: ISIC_0000523_Segmentation.png -> ISIC_0000523.txt
# Processed: ISIC_0000524_Segmentation.png -> ISIC_0000524.txt
# Processed: ISIC_0000528_Segmentation.png -> ISIC_0000528.txt
# Processed: ISIC_0000529_Segmentation.png -> ISIC_0000529.txt
# Processed: ISIC_0000530_Segmentation.png -> ISIC_0000530.txt
# Processed: ISIC_0000531_Segmentation.png -> ISIC_0000531.txt
# Processed: ISIC_0000532_Segmentation.png -> ISIC_0000532.txt
# Processed: ISIC_0000535_Segmentation.png -> ISIC_0000535.txt
# Processed: ISIC_0000536_Segmentation.png -> ISIC_0000536.txt
# Processed: ISIC_0000538_Segmentation.png -> ISIC_0000538.txt
# Processed: ISIC_0000541_Segmentation.png -> ISIC_0000541.txt
# Processed: ISIC_0000542_Segmentation.png -> ISIC_0000542.txt
# Processed: ISIC_0000543_Segmentation.png -> ISIC_0000543.txt
# Processed: ISIC_0000544_Segmentation.png -> ISIC_0000544.txt
# Processed: ISIC_0000545_Segmentation.png -> ISIC_0000545.txt
# Processed: ISIC_0000546_Segmentation.png -> ISIC_0000546.txt
# Processed: ISIC_0000548_Segmentation.png -> ISIC_0000548.txt
# Processed: ISIC_0000551_Segmentation.png -> ISIC_0000551.txt
# Processed: ISIC_0000552_Segmentation.png -> ISIC_0000552.txt
# Processed: ISIC_0000554_Segmentation.png -> ISIC_0000554.txt
# Processed: ISIC_0000555_Segmentation.png -> ISIC_0000555.txt
# Processed: ISIC_0000556_Segmentation.png -> ISIC_0000556.txt
# Processed: ISIC_0000882_Segmentation.png -> ISIC_0000882.txt
# Processed: ISIC_0000900_Segmentation.png -> ISIC_0000900.txt
# Processed: ISIC_0000999_Segmentation.png -> ISIC_0000999.txt
# Processed: ISIC_0001102_Segmentation.png -> ISIC_0001102.txt
# Processed: ISIC_0001105_Segmentation.png -> ISIC_0001105.txt
# Processed: ISIC_0001106_Segmentation.png -> ISIC_0001106.txt
# Processed: ISIC_0001118_Segmentation.png -> ISIC_0001118.txt
# Processed: ISIC_0001119_Segmentation.png -> ISIC_0001119.txt
# Processed: ISIC_0001126_Segmentation.png -> ISIC_0001126.txt
# Processed: ISIC_0001133_Segmentation.png -> ISIC_0001133.txt
# Processed: ISIC_0001134_Segmentation.png -> ISIC_0001134.txt
# Processed: ISIC_0001140_Segmentation.png -> ISIC_0001140.txt
# Processed: ISIC_0001148_Segmentation.png -> ISIC_0001148.txt
# Processed: ISIC_0001152_Segmentation.png -> ISIC_0001152.txt
# Processed: ISIC_0001163_Segmentation.png -> ISIC_0001163.txt
# Processed: ISIC_0001184_Segmentation.png -> ISIC_0001184.txt
# Processed: ISIC_0001187_Segmentation.png -> ISIC_0001187.txt
# Processed: ISIC_0001188_Segmentation.png -> ISIC_0001188.txt
# Processed: ISIC_0001191_Segmentation.png -> ISIC_0001191.txt
# Processed: ISIC_0001212_Segmentation.png -> ISIC_0001212.txt
# Processed: ISIC_0001213_Segmentation.png -> ISIC_0001213.txt
# Processed: ISIC_0001216_Segmentation.png -> ISIC_0001216.txt
# Processed: ISIC_0001247_Segmentation.png -> ISIC_0001247.txt
# Processed: ISIC_0001254_Segmentation.png -> ISIC_0001254.txt
# Processed: ISIC_0001262_Segmentation.png -> ISIC_0001262.txt
# Processed: ISIC_0001267_Segmentation.png -> ISIC_0001267.txt
# Processed: ISIC_0001275_Segmentation.png -> ISIC_0001275.txt
# Processed: ISIC_0001286_Segmentation.png -> ISIC_0001286.txt
# Processed: ISIC_0001292_Segmentation.png -> ISIC_0001292.txt
# Processed: ISIC_0001296_Segmentation.png -> ISIC_0001296.txt
# Processed: ISIC_0001306_Segmentation.png -> ISIC_0001306.txt
# Processed: ISIC_0001367_Segmentation.png -> ISIC_0001367.txt
# Processed: ISIC_0001372_Segmentation.png -> ISIC_0001372.txt
# Processed: ISIC_0001374_Segmentation.png -> ISIC_0001374.txt
# Processed: ISIC_0001385_Segmentation.png -> ISIC_0001385.txt
# Processed: ISIC_0001423_Segmentation.png -> ISIC_0001423.txt
# Processed: ISIC_0001442_Segmentation.png -> ISIC_0001442.txt
# Processed: ISIC_0001449_Segmentation.png -> ISIC_0001449.txt
# Processed: ISIC_0001742_Segmentation.png -> ISIC_0001742.txt
# Processed: ISIC_0002093_Segmentation.png -> ISIC_0002093.txt
# Processed: ISIC_0002206_Segmentation.png -> ISIC_0002206.txt
# Processed: ISIC_0002251_Segmentation.png -> ISIC_0002251.txt
# Processed: ISIC_0002287_Segmentation.png -> ISIC_0002287.txt
# Processed: ISIC_0002353_Segmentation.png -> ISIC_0002353.txt
# Processed: ISIC_0002374_Segmentation.png -> ISIC_0002374.txt
# Processed: ISIC_0002438_Segmentation.png -> ISIC_0002438.txt
# Processed: ISIC_0002439_Segmentation.png -> ISIC_0002439.txt
# Processed: ISIC_0002453_Segmentation.png -> ISIC_0002453.txt
# Processed: ISIC_0002459_Segmentation.png -> ISIC_0002459.txt
# Processed: ISIC_0002469_Segmentation.png -> ISIC_0002469.txt
# Processed: ISIC_0002476_Segmentation.png -> ISIC_0002476.txt
# Processed: ISIC_0002488_Segmentation.png -> ISIC_0002488.txt
# Processed: ISIC_0002489_Segmentation.png -> ISIC_0002489.txt
# Processed: ISIC_0002616_Segmentation.png -> ISIC_0002616.txt
# Processed: ISIC_0002647_Segmentation.png -> ISIC_0002647.txt
# Processed: ISIC_0002780_Segmentation.png -> ISIC_0002780.txt
# Processed: ISIC_0002806_Segmentation.png -> ISIC_0002806.txt
# Processed: ISIC_0002836_Segmentation.png -> ISIC_0002836.txt
# Processed: ISIC_0002879_Segmentation.png -> ISIC_0002879.txt
# Processed: ISIC_0002885_Segmentation.png -> ISIC_0002885.txt
# Processed: ISIC_0002948_Segmentation.png -> ISIC_0002948.txt
# Processed: ISIC_0002975_Segmentation.png -> ISIC_0002975.txt
# Processed: ISIC_0002976_Segmentation.png -> ISIC_0002976.txt
# Processed: ISIC_0003005_Segmentation.png -> ISIC_0003005.txt
# Processed: ISIC_0003051_Segmentation.png -> ISIC_0003051.txt
# Processed: ISIC_0003174_Segmentation.png -> ISIC_0003174.txt
# Processed: ISIC_0003308_Segmentation.png -> ISIC_0003308.txt
# Processed: ISIC_0003346_Segmentation.png -> ISIC_0003346.txt
# Processed: ISIC_0004110_Segmentation.png -> ISIC_0004110.txt
# Processed: ISIC_0004166_Segmentation.png -> ISIC_0004166.txt
# Processed: ISIC_0004168_Segmentation.png -> ISIC_0004168.txt
# Processed: ISIC_0004309_Segmentation.png -> ISIC_0004309.txt
# Processed: ISIC_0004715_Segmentation.png -> ISIC_0004715.txt
# Processed: ISIC_0004985_Segmentation.png -> ISIC_0004985.txt
# Processed: ISIC_0005187_Segmentation.png -> ISIC_0005187.txt
# Processed: ISIC_0005247_Segmentation.png -> ISIC_0005247.txt
# Processed: ISIC_0005548_Segmentation.png -> ISIC_0005548.txt
# Processed: ISIC_0005555_Segmentation.png -> ISIC_0005555.txt
# Processed: ISIC_0005564_Segmentation.png -> ISIC_0005564.txt
# Processed: ISIC_0005620_Segmentation.png -> ISIC_0005620.txt
# Processed: ISIC_0005639_Segmentation.png -> ISIC_0005639.txt
# Processed: ISIC_0005666_Segmentation.png -> ISIC_0005666.txt
# Processed: ISIC_0005787_Segmentation.png -> ISIC_0005787.txt
# Processed: ISIC_0006021_Segmentation.png -> ISIC_0006021.txt
# Processed: ISIC_0006114_Segmentation.png -> ISIC_0006114.txt
# Processed: ISIC_0006326_Segmentation.png -> ISIC_0006326.txt
# Processed: ISIC_0006350_Segmentation.png -> ISIC_0006350.txt
# Processed: ISIC_0006612_Segmentation.png -> ISIC_0006612.txt
# Processed: ISIC_0006776_Segmentation.png -> ISIC_0006776.txt
# Processed: ISIC_0006795_Segmentation.png -> ISIC_0006795.txt
# Processed: ISIC_0006800_Segmentation.png -> ISIC_0006800.txt
# Processed: ISIC_0006940_Segmentation.png -> ISIC_0006940.txt
# Processed: ISIC_0006982_Segmentation.png -> ISIC_0006982.txt
# Processed: ISIC_0007038_Segmentation.png -> ISIC_0007038.txt
# Processed: ISIC_0007087_Segmentation.png -> ISIC_0007087.txt
# Processed: ISIC_0007475_Segmentation.png -> ISIC_0007475.txt
# Processed: ISIC_0007557_Segmentation.png -> ISIC_0007557.txt
# Processed: ISIC_0007760_Segmentation.png -> ISIC_0007760.txt
# Processed: ISIC_0007788_Segmentation.png -> ISIC_0007788.txt
# Processed: ISIC_0008029_Segmentation.png -> ISIC_0008029.txt
# Processed: ISIC_0008145_Segmentation.png -> ISIC_0008145.txt
# Processed: ISIC_0008236_Segmentation.png -> ISIC_0008236.txt
# Processed: ISIC_0008256_Segmentation.png -> ISIC_0008256.txt
# Processed: ISIC_0008280_Segmentation.png -> ISIC_0008280.txt
# Processed: ISIC_0008294_Segmentation.png -> ISIC_0008294.txt
# Processed: ISIC_0008347_Segmentation.png -> ISIC_0008347.txt
# Processed: ISIC_0008396_Segmentation.png -> ISIC_0008396.txt
# Processed: ISIC_0008403_Segmentation.png -> ISIC_0008403.txt
# Processed: ISIC_0008524_Segmentation.png -> ISIC_0008524.txt
# Processed: ISIC_0008528_Segmentation.png -> ISIC_0008528.txt
# Processed: ISIC_0008541_Segmentation.png -> ISIC_0008541.txt
# Processed: ISIC_0008552_Segmentation.png -> ISIC_0008552.txt
# Processed: ISIC_0008785_Segmentation.png -> ISIC_0008785.txt
# Processed: ISIC_0008807_Segmentation.png -> ISIC_0008807.txt
# Processed: ISIC_0008879_Segmentation.png -> ISIC_0008879.txt
# Processed: ISIC_0008913_Segmentation.png -> ISIC_0008913.txt
# Processed: ISIC_0008993_Segmentation.png -> ISIC_0008993.txt
# Processed: ISIC_0009160_Segmentation.png -> ISIC_0009160.txt
# Processed: ISIC_0009165_Segmentation.png -> ISIC_0009165.txt
# Processed: ISIC_0009188_Segmentation.png -> ISIC_0009188.txt
# Processed: ISIC_0009252_Segmentation.png -> ISIC_0009252.txt
# Processed: ISIC_0009297_Segmentation.png -> ISIC_0009297.txt
# Processed: ISIC_0009344_Segmentation.png -> ISIC_0009344.txt
# Processed: ISIC_0009430_Segmentation.png -> ISIC_0009430.txt
# Processed: ISIC_0009504_Segmentation.png -> ISIC_0009504.txt
# Processed: ISIC_0009505_Segmentation.png -> ISIC_0009505.txt
# Processed: ISIC_0009533_Segmentation.png -> ISIC_0009533.txt
# Processed: ISIC_0009583_Segmentation.png -> ISIC_0009583.txt
# Processed: ISIC_0009599_Segmentation.png -> ISIC_0009599.txt
# Processed: ISIC_0009758_Segmentation.png -> ISIC_0009758.txt
# Processed: ISIC_0009800_Segmentation.png -> ISIC_0009800.txt
# Processed: ISIC_0009860_Segmentation.png -> ISIC_0009860.txt
# Processed: ISIC_0009868_Segmentation.png -> ISIC_0009868.txt
# Processed: ISIC_0009870_Segmentation.png -> ISIC_0009870.txt
# Processed: ISIC_0009871_Segmentation.png -> ISIC_0009871.txt
# Processed: ISIC_0009873_Segmentation.png -> ISIC_0009873.txt
# Processed: ISIC_0009875_Segmentation.png -> ISIC_0009875.txt
# Processed: ISIC_0009877_Segmentation.png -> ISIC_0009877.txt
# Processed: ISIC_0009883_Segmentation.png -> ISIC_0009883.txt
# Processed: ISIC_0009884_Segmentation.png -> ISIC_0009884.txt
# Processed: ISIC_0009888_Segmentation.png -> ISIC_0009888.txt
# Processed: ISIC_0009893_Segmentation.png -> ISIC_0009893.txt
# Processed: ISIC_0009895_Segmentation.png -> ISIC_0009895.txt
# Processed: ISIC_0009896_Segmentation.png -> ISIC_0009896.txt
# Processed: ISIC_0009897_Segmentation.png -> ISIC_0009897.txt
# Processed: ISIC_0009899_Segmentation.png -> ISIC_0009899.txt
# Processed: ISIC_0009900_Segmentation.png -> ISIC_0009900.txt
# Processed: ISIC_0009904_Segmentation.png -> ISIC_0009904.txt
# Processed: ISIC_0009905_Segmentation.png -> ISIC_0009905.txt
# Processed: ISIC_0009909_Segmentation.png -> ISIC_0009909.txt
# Processed: ISIC_0009910_Segmentation.png -> ISIC_0009910.txt
# Processed: ISIC_0009911_Segmentation.png -> ISIC_0009911.txt
# Processed: ISIC_0009912_Segmentation.png -> ISIC_0009912.txt
# Processed: ISIC_0009914_Segmentation.png -> ISIC_0009914.txt
# Processed: ISIC_0009915_Segmentation.png -> ISIC_0009915.txt
# Processed: ISIC_0009917_Segmentation.png -> ISIC_0009917.txt
# Processed: ISIC_0009919_Segmentation.png -> ISIC_0009919.txt
# Processed: ISIC_0009921_Segmentation.png -> ISIC_0009921.txt
# Processed: ISIC_0009925_Segmentation.png -> ISIC_0009925.txt
# Processed: ISIC_0009929_Segmentation.png -> ISIC_0009929.txt
# Processed: ISIC_0009932_Segmentation.png -> ISIC_0009932.txt
# Processed: ISIC_0009933_Segmentation.png -> ISIC_0009933.txt
# Processed: ISIC_0009934_Segmentation.png -> ISIC_0009934.txt
# Processed: ISIC_0009935_Segmentation.png -> ISIC_0009935.txt
# Processed: ISIC_0009936_Segmentation.png -> ISIC_0009936.txt
# Processed: ISIC_0009937_Segmentation.png -> ISIC_0009937.txt
# Processed: ISIC_0009938_Segmentation.png -> ISIC_0009938.txt
# Processed: ISIC_0009939_Segmentation.png -> ISIC_0009939.txt
# Processed: ISIC_0009940_Segmentation.png -> ISIC_0009940.txt
# Processed: ISIC_0009941_Segmentation.png -> ISIC_0009941.txt
# Processed: ISIC_0009942_Segmentation.png -> ISIC_0009942.txt
# Processed: ISIC_0009944_Segmentation.png -> ISIC_0009944.txt
# Processed: ISIC_0009947_Segmentation.png -> ISIC_0009947.txt
# Processed: ISIC_0009949_Segmentation.png -> ISIC_0009949.txt
# Processed: ISIC_0009950_Segmentation.png -> ISIC_0009950.txt
# Processed: ISIC_0009951_Segmentation.png -> ISIC_0009951.txt
# Processed: ISIC_0009953_Segmentation.png -> ISIC_0009953.txt
# Processed: ISIC_0009960_Segmentation.png -> ISIC_0009960.txt
# Processed: ISIC_0009961_Segmentation.png -> ISIC_0009961.txt
# Processed: ISIC_0009962_Segmentation.png -> ISIC_0009962.txt
# Processed: ISIC_0009963_Segmentation.png -> ISIC_0009963.txt
# Processed: ISIC_0009964_Segmentation.png -> ISIC_0009964.txt
# Processed: ISIC_0009966_Segmentation.png -> ISIC_0009966.txt
# Processed: ISIC_0009967_Segmentation.png -> ISIC_0009967.txt
# Processed: ISIC_0009968_Segmentation.png -> ISIC_0009968.txt
# Processed: ISIC_0009969_Segmentation.png -> ISIC_0009969.txt
# Processed: ISIC_0009971_Segmentation.png -> ISIC_0009971.txt
# Processed: ISIC_0009972_Segmentation.png -> ISIC_0009972.txt
# Processed: ISIC_0009973_Segmentation.png -> ISIC_0009973.txt
# Processed: ISIC_0009974_Segmentation.png -> ISIC_0009974.txt
# Processed: ISIC_0009975_Segmentation.png -> ISIC_0009975.txt
# Processed: ISIC_0009976_Segmentation.png -> ISIC_0009976.txt
# Processed: ISIC_0009978_Segmentation.png -> ISIC_0009978.txt
# Processed: ISIC_0009979_Segmentation.png -> ISIC_0009979.txt
# Processed: ISIC_0009981_Segmentation.png -> ISIC_0009981.txt
# Processed: ISIC_0009983_Segmentation.png -> ISIC_0009983.txt
# Processed: ISIC_0009986_Segmentation.png -> ISIC_0009986.txt
# Processed: ISIC_0009987_Segmentation.png -> ISIC_0009987.txt
# Processed: ISIC_0009991_Segmentation.png -> ISIC_0009991.txt
# Processed: ISIC_0009995_Segmentation.png -> ISIC_0009995.txt
# Processed: ISIC_0010000_Segmentation.png -> ISIC_0010000.txt
# Processed: ISIC_0010001_Segmentation.png -> ISIC_0010001.txt
# Processed: ISIC_0010002_Segmentation.png -> ISIC_0010002.txt
# Processed: ISIC_0010003_Segmentation.png -> ISIC_0010003.txt
# Processed: ISIC_0010005_Segmentation.png -> ISIC_0010005.txt
# Processed: ISIC_0010006_Segmentation.png -> ISIC_0010006.txt
# Processed: ISIC_0010010_Segmentation.png -> ISIC_0010010.txt
# Processed: ISIC_0010014_Segmentation.png -> ISIC_0010014.txt
# Processed: ISIC_0010015_Segmentation.png -> ISIC_0010015.txt
# Processed: ISIC_0010017_Segmentation.png -> ISIC_0010017.txt
# Processed: ISIC_0010019_Segmentation.png -> ISIC_0010019.txt
# Processed: ISIC_0010021_Segmentation.png -> ISIC_0010021.txt
# Processed: ISIC_0010022_Segmentation.png -> ISIC_0010022.txt
# Processed: ISIC_0010024_Segmentation.png -> ISIC_0010024.txt
# Processed: ISIC_0010025_Segmentation.png -> ISIC_0010025.txt
# Processed: ISIC_0010029_Segmentation.png -> ISIC_0010029.txt
# Processed: ISIC_0010032_Segmentation.png -> ISIC_0010032.txt
# Processed: ISIC_0010035_Segmentation.png -> ISIC_0010035.txt
# Processed: ISIC_0010036_Segmentation.png -> ISIC_0010036.txt
# Processed: ISIC_0010040_Segmentation.png -> ISIC_0010040.txt
# Processed: ISIC_0010042_Segmentation.png -> ISIC_0010042.txt
# Processed: ISIC_0010043_Segmentation.png -> ISIC_0010043.txt
# Processed: ISIC_0010044_Segmentation.png -> ISIC_0010044.txt
# Processed: ISIC_0010046_Segmentation.png -> ISIC_0010046.txt
# Processed: ISIC_0010051_Segmentation.png -> ISIC_0010051.txt
# Processed: ISIC_0010052_Segmentation.png -> ISIC_0010052.txt
# Processed: ISIC_0010053_Segmentation.png -> ISIC_0010053.txt
# Processed: ISIC_0010054_Segmentation.png -> ISIC_0010054.txt
# Processed: ISIC_0010056_Segmentation.png -> ISIC_0010056.txt
# Processed: ISIC_0010057_Segmentation.png -> ISIC_0010057.txt
# Processed: ISIC_0010060_Segmentation.png -> ISIC_0010060.txt
# Processed: ISIC_0010063_Segmentation.png -> ISIC_0010063.txt
# Processed: ISIC_0010064_Segmentation.png -> ISIC_0010064.txt
# Processed: ISIC_0010065_Segmentation.png -> ISIC_0010065.txt
# Processed: ISIC_0010066_Segmentation.png -> ISIC_0010066.txt
# Processed: ISIC_0010067_Segmentation.png -> ISIC_0010067.txt
# Processed: ISIC_0010068_Segmentation.png -> ISIC_0010068.txt
# Processed: ISIC_0010069_Segmentation.png -> ISIC_0010069.txt
# Processed: ISIC_0010070_Segmentation.png -> ISIC_0010070.txt
# Processed: ISIC_0010071_Segmentation.png -> ISIC_0010071.txt
# Processed: ISIC_0010074_Segmentation.png -> ISIC_0010074.txt
# Processed: ISIC_0010075_Segmentation.png -> ISIC_0010075.txt
# Processed: ISIC_0010078_Segmentation.png -> ISIC_0010078.txt
# Processed: ISIC_0010079_Segmentation.png -> ISIC_0010079.txt
# Processed: ISIC_0010080_Segmentation.png -> ISIC_0010080.txt
# Processed: ISIC_0010081_Segmentation.png -> ISIC_0010081.txt
# Processed: ISIC_0010083_Segmentation.png -> ISIC_0010083.txt
# Processed: ISIC_0010086_Segmentation.png -> ISIC_0010086.txt
# Processed: ISIC_0010087_Segmentation.png -> ISIC_0010087.txt
# Processed: ISIC_0010090_Segmentation.png -> ISIC_0010090.txt
# Processed: ISIC_0010091_Segmentation.png -> ISIC_0010091.txt
# Processed: ISIC_0010093_Segmentation.png -> ISIC_0010093.txt
# Processed: ISIC_0010094_Segmentation.png -> ISIC_0010094.txt
# Processed: ISIC_0010101_Segmentation.png -> ISIC_0010101.txt
# Processed: ISIC_0010102_Segmentation.png -> ISIC_0010102.txt
# Processed: ISIC_0010104_Segmentation.png -> ISIC_0010104.txt
# Processed: ISIC_0010105_Segmentation.png -> ISIC_0010105.txt
# Processed: ISIC_0010168_Segmentation.png -> ISIC_0010168.txt
# Processed: ISIC_0010169_Segmentation.png -> ISIC_0010169.txt
# Processed: ISIC_0010170_Segmentation.png -> ISIC_0010170.txt
# Processed: ISIC_0010174_Segmentation.png -> ISIC_0010174.txt
# Processed: ISIC_0010176_Segmentation.png -> ISIC_0010176.txt
# Processed: ISIC_0010177_Segmentation.png -> ISIC_0010177.txt
# Processed: ISIC_0010178_Segmentation.png -> ISIC_0010178.txt
# Processed: ISIC_0010182_Segmentation.png -> ISIC_0010182.txt
# Processed: ISIC_0010184_Segmentation.png -> ISIC_0010184.txt
# Processed: ISIC_0010185_Segmentation.png -> ISIC_0010185.txt
# Processed: ISIC_0010186_Segmentation.png -> ISIC_0010186.txt
# Processed: ISIC_0010189_Segmentation.png -> ISIC_0010189.txt
# Processed: ISIC_0010191_Segmentation.png -> ISIC_0010191.txt
# Processed: ISIC_0010194_Segmentation.png -> ISIC_0010194.txt
# Processed: ISIC_0010203_Segmentation.png -> ISIC_0010203.txt
# Processed: ISIC_0010204_Segmentation.png -> ISIC_0010204.txt
# Processed: ISIC_0010205_Segmentation.png -> ISIC_0010205.txt
# Processed: ISIC_0010212_Segmentation.png -> ISIC_0010212.txt
# Processed: ISIC_0010213_Segmentation.png -> ISIC_0010213.txt
# Processed: ISIC_0010218_Segmentation.png -> ISIC_0010218.txt
# Processed: ISIC_0010219_Segmentation.png -> ISIC_0010219.txt
# Processed: ISIC_0010220_Segmentation.png -> ISIC_0010220.txt
# Processed: ISIC_0010222_Segmentation.png -> ISIC_0010222.txt
# Processed: ISIC_0010223_Segmentation.png -> ISIC_0010223.txt
# Processed: ISIC_0010225_Segmentation.png -> ISIC_0010225.txt
# Processed: ISIC_0010226_Segmentation.png -> ISIC_0010226.txt
# Processed: ISIC_0010227_Segmentation.png -> ISIC_0010227.txt
# Processed: ISIC_0010228_Segmentation.png -> ISIC_0010228.txt
# Processed: ISIC_0010230_Segmentation.png -> ISIC_0010230.txt
# Processed: ISIC_0010232_Segmentation.png -> ISIC_0010232.txt
# Processed: ISIC_0010233_Segmentation.png -> ISIC_0010233.txt
# Processed: ISIC_0010235_Segmentation.png -> ISIC_0010235.txt
# Processed: ISIC_0010236_Segmentation.png -> ISIC_0010236.txt
# Processed: ISIC_0010237_Segmentation.png -> ISIC_0010237.txt
# Processed: ISIC_0010239_Segmentation.png -> ISIC_0010239.txt
# Processed: ISIC_0010240_Segmentation.png -> ISIC_0010240.txt
# Processed: ISIC_0010241_Segmentation.png -> ISIC_0010241.txt
# Processed: ISIC_0010242_Segmentation.png -> ISIC_0010242.txt
# Processed: ISIC_0010244_Segmentation.png -> ISIC_0010244.txt
# Processed: ISIC_0010246_Segmentation.png -> ISIC_0010246.txt
# Processed: ISIC_0010247_Segmentation.png -> ISIC_0010247.txt
# Processed: ISIC_0010248_Segmentation.png -> ISIC_0010248.txt
# Processed: ISIC_0010249_Segmentation.png -> ISIC_0010249.txt
# Processed: ISIC_0010251_Segmentation.png -> ISIC_0010251.txt
# Processed: ISIC_0010252_Segmentation.png -> ISIC_0010252.txt
# Processed: ISIC_0010256_Segmentation.png -> ISIC_0010256.txt
# Processed: ISIC_0010262_Segmentation.png -> ISIC_0010262.txt
# Processed: ISIC_0010263_Segmentation.png -> ISIC_0010263.txt
# Processed: ISIC_0010264_Segmentation.png -> ISIC_0010264.txt
# Processed: ISIC_0010265_Segmentation.png -> ISIC_0010265.txt
# Processed: ISIC_0010266_Segmentation.png -> ISIC_0010266.txt
# Processed: ISIC_0010267_Segmentation.png -> ISIC_0010267.txt
# Processed: ISIC_0010317_Segmentation.png -> ISIC_0010317.txt
# Processed: ISIC_0010318_Segmentation.png -> ISIC_0010318.txt
# Processed: ISIC_0010319_Segmentation.png -> ISIC_0010319.txt
# Processed: ISIC_0010320_Segmentation.png -> ISIC_0010320.txt
# Processed: ISIC_0010321_Segmentation.png -> ISIC_0010321.txt
# Processed: ISIC_0010322_Segmentation.png -> ISIC_0010322.txt
# Processed: ISIC_0010323_Segmentation.png -> ISIC_0010323.txt
# Processed: ISIC_0010324_Segmentation.png -> ISIC_0010324.txt
# Processed: ISIC_0010325_Segmentation.png -> ISIC_0010325.txt
# Processed: ISIC_0010327_Segmentation.png -> ISIC_0010327.txt
# Processed: ISIC_0010329_Segmentation.png -> ISIC_0010329.txt
# Processed: ISIC_0010330_Segmentation.png -> ISIC_0010330.txt
# Processed: ISIC_0010332_Segmentation.png -> ISIC_0010332.txt
# Processed: ISIC_0010333_Segmentation.png -> ISIC_0010333.txt
# Processed: ISIC_0010334_Segmentation.png -> ISIC_0010334.txt
# Processed: ISIC_0010335_Segmentation.png -> ISIC_0010335.txt
# Processed: ISIC_0010337_Segmentation.png -> ISIC_0010337.txt
# Processed: ISIC_0010339_Segmentation.png -> ISIC_0010339.txt
# Processed: ISIC_0010341_Segmentation.png -> ISIC_0010341.txt
# Processed: ISIC_0010342_Segmentation.png -> ISIC_0010342.txt
# Processed: ISIC_0010344_Segmentation.png -> ISIC_0010344.txt
# Processed: ISIC_0010349_Segmentation.png -> ISIC_0010349.txt
# Processed: ISIC_0010350_Segmentation.png -> ISIC_0010350.txt
# Processed: ISIC_0010351_Segmentation.png -> ISIC_0010351.txt
# Processed: ISIC_0010352_Segmentation.png -> ISIC_0010352.txt
# Processed: ISIC_0010356_Segmentation.png -> ISIC_0010356.txt
# Processed: ISIC_0010357_Segmentation.png -> ISIC_0010357.txt
# Processed: ISIC_0010358_Segmentation.png -> ISIC_0010358.txt
# Processed: ISIC_0010361_Segmentation.png -> ISIC_0010361.txt
# Processed: ISIC_0010362_Segmentation.png -> ISIC_0010362.txt
# Processed: ISIC_0010364_Segmentation.png -> ISIC_0010364.txt
# Processed: ISIC_0010365_Segmentation.png -> ISIC_0010365.txt
# Processed: ISIC_0010367_Segmentation.png -> ISIC_0010367.txt
# Processed: ISIC_0010370_Segmentation.png -> ISIC_0010370.txt
# Processed: ISIC_0010371_Segmentation.png -> ISIC_0010371.txt
# Processed: ISIC_0010372_Segmentation.png -> ISIC_0010372.txt
# Processed: ISIC_0010380_Segmentation.png -> ISIC_0010380.txt
# Processed: ISIC_0010382_Segmentation.png -> ISIC_0010382.txt
# Processed: ISIC_0010435_Segmentation.png -> ISIC_0010435.txt
# Processed: ISIC_0010436_Segmentation.png -> ISIC_0010436.txt
# Processed: ISIC_0010438_Segmentation.png -> ISIC_0010438.txt
# Processed: ISIC_0010439_Segmentation.png -> ISIC_0010439.txt
# Processed: ISIC_0010440_Segmentation.png -> ISIC_0010440.txt
# Processed: ISIC_0010441_Segmentation.png -> ISIC_0010441.txt
# Processed: ISIC_0010442_Segmentation.png -> ISIC_0010442.txt
# Processed: ISIC_0010443_Segmentation.png -> ISIC_0010443.txt
# Processed: ISIC_0010445_Segmentation.png -> ISIC_0010445.txt
# Processed: ISIC_0010447_Segmentation.png -> ISIC_0010447.txt
# Processed: ISIC_0010450_Segmentation.png -> ISIC_0010450.txt
# Processed: ISIC_0010455_Segmentation.png -> ISIC_0010455.txt
# Processed: ISIC_0010457_Segmentation.png -> ISIC_0010457.txt
# Processed: ISIC_0010458_Segmentation.png -> ISIC_0010458.txt
# Processed: ISIC_0010459_Segmentation.png -> ISIC_0010459.txt
# Processed: ISIC_0010461_Segmentation.png -> ISIC_0010461.txt
# Processed: ISIC_0010462_Segmentation.png -> ISIC_0010462.txt
# Processed: ISIC_0010464_Segmentation.png -> ISIC_0010464.txt
# Processed: ISIC_0010465_Segmentation.png -> ISIC_0010465.txt
# Processed: ISIC_0010466_Segmentation.png -> ISIC_0010466.txt
# Processed: ISIC_0010467_Segmentation.png -> ISIC_0010467.txt
# Processed: ISIC_0010468_Segmentation.png -> ISIC_0010468.txt
# Processed: ISIC_0010471_Segmentation.png -> ISIC_0010471.txt
# Processed: ISIC_0010472_Segmentation.png -> ISIC_0010472.txt
# Processed: ISIC_0010473_Segmentation.png -> ISIC_0010473.txt
# Processed: ISIC_0010475_Segmentation.png -> ISIC_0010475.txt
# Processed: ISIC_0010476_Segmentation.png -> ISIC_0010476.txt
# Processed: ISIC_0010479_Segmentation.png -> ISIC_0010479.txt
# Processed: ISIC_0010480_Segmentation.png -> ISIC_0010480.txt
# Processed: ISIC_0010481_Segmentation.png -> ISIC_0010481.txt
# Processed: ISIC_0010487_Segmentation.png -> ISIC_0010487.txt
# Processed: ISIC_0010488_Segmentation.png -> ISIC_0010488.txt
# Processed: ISIC_0010490_Segmentation.png -> ISIC_0010490.txt
# Processed: ISIC_0010491_Segmentation.png -> ISIC_0010491.txt
# Processed: ISIC_0010492_Segmentation.png -> ISIC_0010492.txt
# Processed: ISIC_0010493_Segmentation.png -> ISIC_0010493.txt
# Processed: ISIC_0010495_Segmentation.png -> ISIC_0010495.txt
# Processed: ISIC_0010496_Segmentation.png -> ISIC_0010496.txt
# Processed: ISIC_0010497_Segmentation.png -> ISIC_0010497.txt
# Processed: ISIC_0010554_Segmentation.png -> ISIC_0010554.txt
# Processed: ISIC_0010557_Segmentation.png -> ISIC_0010557.txt
# Processed: ISIC_0010558_Segmentation.png -> ISIC_0010558.txt
# Processed: ISIC_0010562_Segmentation.png -> ISIC_0010562.txt
# Processed: ISIC_0010566_Segmentation.png -> ISIC_0010566.txt
# Processed: ISIC_0010567_Segmentation.png -> ISIC_0010567.txt
# Processed: ISIC_0010568_Segmentation.png -> ISIC_0010568.txt
# Processed: ISIC_0010569_Segmentation.png -> ISIC_0010569.txt
# Processed: ISIC_0010570_Segmentation.png -> ISIC_0010570.txt
# Processed: ISIC_0010571_Segmentation.png -> ISIC_0010571.txt
# Processed: ISIC_0010572_Segmentation.png -> ISIC_0010572.txt
# Processed: ISIC_0010573_Segmentation.png -> ISIC_0010573.txt
# Processed: ISIC_0010575_Segmentation.png -> ISIC_0010575.txt
# Processed: ISIC_0010576_Segmentation.png -> ISIC_0010576.txt
# Processed: ISIC_0010577_Segmentation.png -> ISIC_0010577.txt
# Processed: ISIC_0010581_Segmentation.png -> ISIC_0010581.txt
# Processed: ISIC_0010585_Segmentation.png -> ISIC_0010585.txt
# Processed: ISIC_0010586_Segmentation.png -> ISIC_0010586.txt
# Processed: ISIC_0010589_Segmentation.png -> ISIC_0010589.txt
# Processed: ISIC_0010590_Segmentation.png -> ISIC_0010590.txt
# Processed: ISIC_0010593_Segmentation.png -> ISIC_0010593.txt
# Processed: ISIC_0010594_Segmentation.png -> ISIC_0010594.txt
# Processed: ISIC_0010595_Segmentation.png -> ISIC_0010595.txt
# Processed: ISIC_0010602_Segmentation.png -> ISIC_0010602.txt
# Processed: ISIC_0010603_Segmentation.png -> ISIC_0010603.txt
# Processed: ISIC_0010605_Segmentation.png -> ISIC_0010605.txt
# Processed: ISIC_0010844_Segmentation.png -> ISIC_0010844.txt
# Processed: ISIC_0010848_Segmentation.png -> ISIC_0010848.txt
# Processed: ISIC_0010849_Segmentation.png -> ISIC_0010849.txt
# Processed: ISIC_0010850_Segmentation.png -> ISIC_0010850.txt
# Processed: ISIC_0010851_Segmentation.png -> ISIC_0010851.txt
# Processed: ISIC_0010852_Segmentation.png -> ISIC_0010852.txt
# Processed: ISIC_0010853_Segmentation.png -> ISIC_0010853.txt
# Processed: ISIC_0010857_Segmentation.png -> ISIC_0010857.txt
# Processed: ISIC_0010858_Segmentation.png -> ISIC_0010858.txt
# Processed: ISIC_0010860_Segmentation.png -> ISIC_0010860.txt
# Processed: ISIC_0010861_Segmentation.png -> ISIC_0010861.txt
# Processed: ISIC_0010862_Segmentation.png -> ISIC_0010862.txt
# Processed: ISIC_0010864_Segmentation.png -> ISIC_0010864.txt
# Processed: ISIC_0011079_Segmentation.png -> ISIC_0011079.txt
# Processed: ISIC_0011082_Segmentation.png -> ISIC_0011082.txt
# Processed: ISIC_0011084_Segmentation.png -> ISIC_0011084.txt
# Processed: ISIC_0011085_Segmentation.png -> ISIC_0011085.txt
# Processed: ISIC_0011088_Segmentation.png -> ISIC_0011088.txt
# Processed: ISIC_0011095_Segmentation.png -> ISIC_0011095.txt
# Processed: ISIC_0011097_Segmentation.png -> ISIC_0011097.txt
# Processed: ISIC_0011099_Segmentation.png -> ISIC_0011099.txt
# Processed: ISIC_0011100_Segmentation.png -> ISIC_0011100.txt
# Processed: ISIC_0011102_Segmentation.png -> ISIC_0011102.txt
# Processed: ISIC_0011105_Segmentation.png -> ISIC_0011105.txt
# Processed: ISIC_0011109_Segmentation.png -> ISIC_0011109.txt
# Processed: ISIC_0011114_Segmentation.png -> ISIC_0011114.txt
# Processed: ISIC_0011115_Segmentation.png -> ISIC_0011115.txt
# Processed: ISIC_0011116_Segmentation.png -> ISIC_0011116.txt
# Processed: ISIC_0011117_Segmentation.png -> ISIC_0011117.txt
# Processed: ISIC_0011118_Segmentation.png -> ISIC_0011118.txt
# Processed: ISIC_0011119_Segmentation.png -> ISIC_0011119.txt
# Processed: ISIC_0011120_Segmentation.png -> ISIC_0011120.txt
# Processed: ISIC_0011121_Segmentation.png -> ISIC_0011121.txt
# Processed: ISIC_0011123_Segmentation.png -> ISIC_0011123.txt
# Processed: ISIC_0011124_Segmentation.png -> ISIC_0011124.txt
# Processed: ISIC_0011125_Segmentation.png -> ISIC_0011125.txt
# Processed: ISIC_0011126_Segmentation.png -> ISIC_0011126.txt
# Processed: ISIC_0011127_Segmentation.png -> ISIC_0011127.txt
# Processed: ISIC_0011128_Segmentation.png -> ISIC_0011128.txt
# Processed: ISIC_0011130_Segmentation.png -> ISIC_0011130.txt
# Processed: ISIC_0011131_Segmentation.png -> ISIC_0011131.txt
# Processed: ISIC_0011135_Segmentation.png -> ISIC_0011135.txt
# Processed: ISIC_0011136_Segmentation.png -> ISIC_0011136.txt
# Processed: ISIC_0011137_Segmentation.png -> ISIC_0011137.txt
# Processed: ISIC_0011139_Segmentation.png -> ISIC_0011139.txt
# Processed: ISIC_0011140_Segmentation.png -> ISIC_0011140.txt
# Processed: ISIC_0011141_Segmentation.png -> ISIC_0011141.txt
# Processed: ISIC_0011144_Segmentation.png -> ISIC_0011144.txt
# Processed: ISIC_0011145_Segmentation.png -> ISIC_0011145.txt
# Processed: ISIC_0011146_Segmentation.png -> ISIC_0011146.txt
# Processed: ISIC_0011156_Segmentation.png -> ISIC_0011156.txt
# Processed: ISIC_0011157_Segmentation.png -> ISIC_0011157.txt
# Processed: ISIC_0011158_Segmentation.png -> ISIC_0011158.txt
# Processed: ISIC_0011159_Segmentation.png -> ISIC_0011159.txt
# Processed: ISIC_0011161_Segmentation.png -> ISIC_0011161.txt
# Processed: ISIC_0011163_Segmentation.png -> ISIC_0011163.txt
# Processed: ISIC_0011164_Segmentation.png -> ISIC_0011164.txt
# Processed: ISIC_0011165_Segmentation.png -> ISIC_0011165.txt
# Processed: ISIC_0011166_Segmentation.png -> ISIC_0011166.txt
# Processed: ISIC_0011169_Segmentation.png -> ISIC_0011169.txt
# Processed: ISIC_0011170_Segmentation.png -> ISIC_0011170.txt
# Processed: ISIC_0011173_Segmentation.png -> ISIC_0011173.txt
# Processed: ISIC_0011199_Segmentation.png -> ISIC_0011199.txt
# Processed: ISIC_0011200_Segmentation.png -> ISIC_0011200.txt
# Processed: ISIC_0011202_Segmentation.png -> ISIC_0011202.txt
# Processed: ISIC_0011203_Segmentation.png -> ISIC_0011203.txt
# Processed: ISIC_0011207_Segmentation.png -> ISIC_0011207.txt
# Processed: ISIC_0011208_Segmentation.png -> ISIC_0011208.txt
# Processed: ISIC_0011210_Segmentation.png -> ISIC_0011210.txt
# Processed: ISIC_0011211_Segmentation.png -> ISIC_0011211.txt
# Processed: ISIC_0011212_Segmentation.png -> ISIC_0011212.txt
# Processed: ISIC_0011214_Segmentation.png -> ISIC_0011214.txt
# Processed: ISIC_0011215_Segmentation.png -> ISIC_0011215.txt
# Processed: ISIC_0011217_Segmentation.png -> ISIC_0011217.txt
# Processed: ISIC_0011218_Segmentation.png -> ISIC_0011218.txt
# Processed: ISIC_0011220_Segmentation.png -> ISIC_0011220.txt
# Processed: ISIC_0011223_Segmentation.png -> ISIC_0011223.txt
# Processed: ISIC_0011225_Segmentation.png -> ISIC_0011225.txt
# Processed: ISIC_0011226_Segmentation.png -> ISIC_0011226.txt
# Processed: ISIC_0011228_Segmentation.png -> ISIC_0011228.txt
# Processed: ISIC_0011229_Segmentation.png -> ISIC_0011229.txt
# Processed: ISIC_0011230_Segmentation.png -> ISIC_0011230.txt
# Processed: ISIC_0011295_Segmentation.png -> ISIC_0011295.txt
# Processed: ISIC_0011296_Segmentation.png -> ISIC_0011296.txt
# Processed: ISIC_0011297_Segmentation.png -> ISIC_0011297.txt
# Processed: ISIC_0011299_Segmentation.png -> ISIC_0011299.txt
# Processed: ISIC_0011301_Segmentation.png -> ISIC_0011301.txt
# Processed: ISIC_0011303_Segmentation.png -> ISIC_0011303.txt
# Processed: ISIC_0011304_Segmentation.png -> ISIC_0011304.txt
# Processed: ISIC_0011306_Segmentation.png -> ISIC_0011306.txt
# Processed: ISIC_0011315_Segmentation.png -> ISIC_0011315.txt
# Processed: ISIC_0011317_Segmentation.png -> ISIC_0011317.txt
# Processed: ISIC_0011322_Segmentation.png -> ISIC_0011322.txt
# Processed: ISIC_0011323_Segmentation.png -> ISIC_0011323.txt
# Processed: ISIC_0011324_Segmentation.png -> ISIC_0011324.txt
# Processed: ISIC_0011326_Segmentation.png -> ISIC_0011326.txt
# Processed: ISIC_0011327_Segmentation.png -> ISIC_0011327.txt
# Processed: ISIC_0011328_Segmentation.png -> ISIC_0011328.txt
# Processed: ISIC_0011329_Segmentation.png -> ISIC_0011329.txt
# Processed: ISIC_0011330_Segmentation.png -> ISIC_0011330.txt
# Processed: ISIC_0011331_Segmentation.png -> ISIC_0011331.txt
# Processed: ISIC_0011332_Segmentation.png -> ISIC_0011332.txt
# Processed: ISIC_0011334_Segmentation.png -> ISIC_0011334.txt
# Processed: ISIC_0011339_Segmentation.png -> ISIC_0011339.txt
# Processed: ISIC_0011341_Segmentation.png -> ISIC_0011341.txt
# Processed: ISIC_0011343_Segmentation.png -> ISIC_0011343.txt
# Processed: ISIC_0011345_Segmentation.png -> ISIC_0011345.txt
# Processed: ISIC_0011346_Segmentation.png -> ISIC_0011346.txt
# Processed: ISIC_0011347_Segmentation.png -> ISIC_0011347.txt
# Processed: ISIC_0011348_Segmentation.png -> ISIC_0011348.txt
# Processed: ISIC_0011350_Segmentation.png -> ISIC_0011350.txt
# Processed: ISIC_0011352_Segmentation.png -> ISIC_0011352.txt
# Processed: ISIC_0011353_Segmentation.png -> ISIC_0011353.txt
# Processed: ISIC_0011354_Segmentation.png -> ISIC_0011354.txt
# Processed: ISIC_0011356_Segmentation.png -> ISIC_0011356.txt
# Processed: ISIC_0011357_Segmentation.png -> ISIC_0011357.txt
# Processed: ISIC_0011358_Segmentation.png -> ISIC_0011358.txt
# Processed: ISIC_0011360_Segmentation.png -> ISIC_0011360.txt
# Processed: ISIC_0011361_Segmentation.png -> ISIC_0011361.txt
# Processed: ISIC_0011362_Segmentation.png -> ISIC_0011362.txt
# Processed: ISIC_0011366_Segmentation.png -> ISIC_0011366.txt
# Processed: ISIC_0011372_Segmentation.png -> ISIC_0011372.txt
# Processed: ISIC_0011373_Segmentation.png -> ISIC_0011373.txt
# Processed: ISIC_0011378_Segmentation.png -> ISIC_0011378.txt
# Processed: ISIC_0011380_Segmentation.png -> ISIC_0011380.txt
# Processed: ISIC_0011382_Segmentation.png -> ISIC_0011382.txt
# Processed: ISIC_0011383_Segmentation.png -> ISIC_0011383.txt
# Processed: ISIC_0011385_Segmentation.png -> ISIC_0011385.txt
# Processed: ISIC_0011387_Segmentation.png -> ISIC_0011387.txt
# Processed: ISIC_0011390_Segmentation.png -> ISIC_0011390.txt
# Processed: ISIC_0011393_Segmentation.png -> ISIC_0011393.txt
# Processed: ISIC_0011397_Segmentation.png -> ISIC_0011397.txt
# Processed: ISIC_0011398_Segmentation.png -> ISIC_0011398.txt
# Processed: ISIC_0011400_Segmentation.png -> ISIC_0011400.txt
# Processed: ISIC_0011402_Segmentation.png -> ISIC_0011402.txt

# %%
model.classes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 model.classes
#
# NameError: name 'model' is not defined

# %%
import os
import shutil

# Define the paths for your folders
base_folder = 'segmentation\dataset\ISBI2016_ISIC_Part3B_Training_Data'  # Replace with your actual folder path
image_folder = os.path.join(base_folder, 'image')
mask_folder = os.path.join(base_folder, 'mask')

# Create the image and mask folders if they don't exist
os.makedirs(image_folder, exist_ok=True)
os.makedirs(mask_folder, exist_ok=True)

# Counters to track progress
image_count = 0
mask_count = 0

# Iterate through all files in the base folder
for filename in os.listdir(base_folder):
    # Skip directories and the newly created folders
    source_path = os.path.join(base_folder, filename)
    if os.path.isdir(source_path) or filename in ['image', 'mask']:
        continue
        
    # Copy image files (.jpg) to the image folder
    if filename.endswith('.jpg'):
        shutil.copy2(source_path, os.path.join(image_folder, filename))
        image_count += 1
    
    # Copy mask files (_Segmentation.png) to the mask folder
    elif filename.endswith('_Segmentation.png'):
        shutil.copy2(source_path, os.path.join(mask_folder, filename))
        mask_count += 1

print(f"Copied {image_count} images to: {image_folder}")
print(f"Copied {mask_count} masks to: {mask_folder}")
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Viren\AppData\Local\Temp\ipykernel_9880\2765482793.py:5: SyntaxWarning: invalid escape sequence '\d'
#   base_folder = 'segmentation\dataset\ISBI2016_ISIC_Part3B_Training_Data'  # Replace with your actual folder path
# Copied 900 images to: segmentation\dataset\ISBI2016_ISIC_Part3B_Training_Data\image
# Copied 900 masks to: segmentation\dataset\ISBI2016_ISIC_Part3B_Training_Data\mask

# %%
model_path = 'segmentation/segment-m-train/weights/best.pt'
image_path = 'segmentation\dataset\ISBI2016_ISIC_Part3B_Training_Data\image\ISIC_0000001.jpg'

from ultralytics import YOLO
model = YOLO(model_path) 

results = model(image_path, show_conf=False, verbose=True)

result = results[0]
result.save('seg-res.jpg')
# Out:
# image 1/1 c:\Users\Viren\Desktop\HackNUthon'25 March'25\Reve\segmentation\dataset\ISBI2016_ISIC_Part3B_Training_Data\image\ISIC_0000001.jpg: 480x640 1 0, 574.3ms
# Speed: 2.5ms preprocess, 574.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# 'seg-res.jpg'

# %%
result
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: ultralytics.engine.results.Masks object
# names: {0: '0'}
# obb: None
# orig_img: array([[[255, 254, 255],
#         [236, 228, 229],
#         [255, 254, 255],
#         ...,
#         [255, 255, 254],
#         [234, 230, 229],
#         [255, 255, 254]],
#
#        [[242, 234, 235],
#         [140, 132, 133],
#         [144, 136, 137],
#         ...,
#         [160, 155, 154],
#         [160, 156, 155],
#         [255, 254, 253]],
#
#        [[255, 254, 255],
#         [137, 129, 130],
#         [128, 120, 121],
#         ...,
#         [137, 129, 129],
#         [138, 133, 132],
#         [255, 254, 253]],
#
#        ...,
#
#        [[255, 251, 252],
#         [173, 168, 169],
#         [160, 155, 156],
#         ...,
#         [172, 166, 167],
#         [183, 178, 179],
#         [255, 254, 254]],
#
#        [[233, 231, 231],
#         [173, 171, 171],
#         [167, 165, 165],
#         ...,
#         [175, 170, 171],
#         [189, 184, 185],
#         [242, 240, 240]],
#
#        [[255, 255, 255],
#         [249, 249, 249],
#         [255, 255, 255],
#         ...,
#         [249, 244, 245],
#         [244, 239, 240],
#         [255, 255, 255]]], dtype=uint8)
# orig_shape: (767, 1022)
# path: "c:\\Users\\Viren\\Desktop\\HackNUthon'25 March'25\\Reve\\segmentation\\dataset\\ISBI2016_ISIC_Part3B_Training_Data\\image\\ISIC_0000001.jpg"
# probs: None
# save_dir: None
# speed: {'preprocess': 4.839200002606958, 'inference': 592.3025000010966, 'postprocess': 3.166800001054071}

# %%
model_path = 'throat-obj0detection/weights/best.pt'
image_path = 'Throat Cancer.v1i.yolov11/test/images/2fnukyjthgdrthy_JPG.rf.c6a1e3985768970376a63451766259bb.jpg'

from ultralytics import YOLO
model = YOLO(model_path) 

results = model(image_path, show_conf=False, verbose=True)

result = results[0]
result.save('throat-res.jpg')

detected_classes = []
for box in result.boxes:
    class_id = int(box.cls[0].item())
    class_name = result.names[class_id]
    confidence = box.conf[0].item()
    detected_classes.append({
        'name': class_name,
        'confidence': round(confidence,2)})
    
print(detected_classes[0]["name"])
# Out:
# image 1/1 c:\Users\Viren\Desktop\HackNUthon'25 March'25\Reve\Throat Cancer.v1i.yolov11\test\images\2fnukyjthgdrthy_JPG.rf.c6a1e3985768970376a63451766259bb.jpg: 640x640 2 Non Pharyngitiss, 713.5ms
# Speed: 4.3ms preprocess, 713.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Non Pharyngitis

# %%
detected_classes = []
for box in result.boxes:
    class_id = int(box.cls[0].item())
    class_name = result.names[class_id]
    confidence = box.conf[0].item()
    detected_classes.append({
        'name': class_name,
        'confidence': round(confidence,2)})

# %%
print(detected_classes)
# Out:
# [{'name': 'Non Pharyngitis', 'confidence': 0.55}, {'name': 'Non Pharyngitis', 'confidence': 0.34}]
